# %% [markdown]
# <a href="https://colab.research.google.com/github/emmapraise/New-Project-/blob/master/Sentiment_Analysis_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install torchvision
# Out:
# ...
#     100% |████████████████████████████████| 61kB 2.4MB/s
# ...
#     100% |████████████████████████████████| 2.0MB 12.6MB/s
# ...
#     100% |████████████████████████████████| 591.8MB 19kB/s
# tcmalloc: large alloc 1073750016 bytes == 0x618e4000 @  0x7f655f4c92a4 0x591a07 0x5b5d56 0x502e9a 0x506859 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x502209 0x502f3d 0x506859 0x504c28 0x502540 0x502f3d 0x507641 0x504c28 0x502540 0x502f3d 0x507641
# ...
#   Found existing installation: Pillow 4.0.0
#     Uninstalling Pillow-4.0.0:
#       Successfully uninstalled Pillow-4.0.0
# ...

# %%
import tweepy
from textblob import TextBlob

# %%
consumer_key = '4UVqA44fSYOp1zeFGfsCVuZWf'
consumer_secret = 'eccY5JdQxZOa2uOqaCVguvuhePFBMdXWGpu0hMqpWKmkcO1Qjc'

access_token = '2960988395-EfALUKwhVrslW0vm6fmGwEKIu0Elv9IRR8IjF08'
access_token_secret = 'FH0j7w0Iiqjh35Ek24h0UFUSiWPUeAi3HqCmTDpDHMyhr'

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token = (access_token, access_token_secret)

# %%
api = tweepy.API(auth, wait_on_rate_limit=True) #IT'S MAGIC IT'S MAGIC

# %%
query1 = 'MBuhari'
max_tweets = 10000

# %%
public_tweets = tweepy.Cursor(api.search, q=query1).items(max_tweets)

# %%
for tweet in public_tweets:
  if (tweet.lang == "en") and (not tweet.retweeted) and ('RT @' not in tweet.text): #my filters. MINE!
    print(tweet.text)
    analysis = TextBlob(tweet.text)
    print(analysis.sentiment)
# Out:
# @Legit9jaYouth @yb_ibraheem @AyeeshaMusa1 @comrd_Sadiq @MBuhari Bet why https://t.co/QOOTIlaMqh
# Sentiment(polarity=0.0, subjectivity=0.0)
# @akanimosunday2 @renoomokri @MBuhari @realDonaldTrump Ur using APC ear piece pls remove it and listen again
# Sentiment(polarity=0.0, subjectivity=0.0)
# @renoomokri @MBuhari @GEJonathan FACT
# Sentiment(polarity=0.0, subjectivity=0.0)
# @OfficialPDPNig @MBuhari @atiku Integrity to loot our common wealth again. Am ashamed of PDP.
# Sentiment(polarity=-0.3, subjectivity=0.5)
# when are going to have a president that will eventually end the reoccurrence of #asuustrike in our dear country? I… https://t.co/pXvJnOsWkj
# Sentiment(polarity=0.0, subjectivity=0.0)
# @thecableng @MBuhari How you've now become the face of corruption.
# Sentiment(polarity=0.0, subjectivity=0.0)
# @thebardogbamola @APCNigeria @MBuhari this is a very bad precedence Buhari is setting.
#
# Buhari is a symbol of National division.
# ...
